# %%
# Import

import tensorflow as tf
import numpy as np
import os
import pathlib
import pickle
import time

from network_architectures import *

#from tensorflow.compat.v1 import ConfigProto
#from tensorflow.compat.v1 import InteractiveSession
#config = ConfigProto()
#config.gpu_options.allow_growth = True
#session = InteractiveSession(config=config)

physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

#os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# %load_ext tensorboard
# !rm -rf ./logs/

# %%
# Current path
current_path = pathlib.Path().absolute()

EPOCHS = 20

# %%
# Load tokenized dataset

data_path = os.path.join(current_path,"dataset","por-eng")
if not os.path.exists(data_path):
    os.makedirs(data_path)

input_tensor_train = np.load(os.path.join(data_path,"input_tensor_train.npy"))
input_tensor_val = np.load(os.path.join(data_path,"input_tensor_val.npy"))
target_tensor_train = np.load(os.path.join(data_path,"target_tensor_train.npy"))
target_tensor_train = np.load(os.path.join(data_path,"target_tensor_val.npy"))

with open(os.path.join(data_path,"inp_lang.tokenizer"), 'rb') as handle:
    inp_lang = pickle.load(handle)
    
with open(os.path.join(data_path,"targ_lang.tokenizer"), 'rb') as handle:
    targ_lang = pickle.load(handle)

# %%
# Create dataset of this data

BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = BUFFER_SIZE//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 16]), TensorShape([64, 14]))

# %%
# Define the model

encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder output shape: (batch size, sequence length, units)', sample_output.shape)
print('Encoder Hidden state shape: (batch size, units)', sample_hidden.shape)

attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units)", attention_result.shape)
print("Attention weights shape: (batch_size, sequence_length, 1)", attention_weights.shape)

decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print('Decoder output shape: (batch_size, vocab size)', sample_decoder_output.shape)
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 16, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 16, 1)
# Decoder output shape: (batch_size, vocab size) (64, 9172)

# %%
# Define the Optimizer and loss functions

optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True,
                                                            reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
# Callbacks

checkpoint_dir = "checkpoints"
checkpoint_prefix = os.path.join(current_path,checkpoint_dir,"ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

tensorboard = tf.keras.callbacks.TensorBoard(log_dir='logs')

tensorboard.set_model(encoder)
tensorboard.set_model(decoder)

# %%
# Training function

@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

            loss += loss_function(targ[:, t], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
# Training Loop

for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print(f'Epoch {epoch+1} Batch {batch} Loss {batch_loss.numpy():.4f}')
    # saving (checkpoint) the model every 2 epochs
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix=checkpoint_prefix)

    print(f'Epoch {epoch+1} Loss {total_loss/steps_per_epoch:.4f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function train_step at 0x7f0081115820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function train_step at 0x7f0081115820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method Decoder.call of <network_architectures.Decoder object at 0x7f00101c6670>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Decoder.call of <network_architectures.Decoder object at 0x7f00101c6670>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1 Batch 0 Loss 4.6229
# Epoch 1 Batch 100 Loss 2.2297
# Epoch 1 Batch 200 Loss 2.1512
# Epoch 1 Batch 300 Loss 1.8310
# Epoch 1 Batch 400 Loss 1.6691
# Epoch 1 Batch 500 Loss 1.4347
# Epoch 1 Batch 600 Loss 1.4070
# Epoch 1 Batch 700 Loss 1.3307
# Epoch 1 Batch 800 Loss 1.0963
# Epoch 1 Batch 900 Loss 1.0712
# Epoch 1 Batch 1000 Loss 1.0873
# Epoch 1 Batch 1100 Loss 0.9202
# Epoch 1 Batch 1200 Loss 0.8360
# Epoch 1 Batch 1300 Loss 0.7325
# Epoch 1 Batch 1400 Loss 0.7432
# Epoch 1 Loss 1.3306
# Time taken for 1 epoch 269.17 sec
#
# Epoch 2 Batch 0 Loss 0.5637
# Epoch 2 Batch 100 Loss 0.5250
# Epoch 2 Batch 200 Loss 0.5424
# Epoch 2 Batch 300 Loss 0.5839
# Epoch 2 Batch 400 Loss 0.5072
# Epoch 2 Batch 500 Loss 0.6094
# Epoch 2 Batch 600 Loss 0.6010
# Epoch 2 Batch 700 Loss 0.4828
# Epoch 2 Batch 800 Loss 0.5417
# Epoch 2 Batch 900 Loss 0.5029
# Epoch 2 Batch 1000 Loss 0.3774
# Epoch 2 Batch 1100 Loss 0.4243
# Epoch 2 Batch 1200 Loss 0.4888
# Epoch 2 Batch 1300 Loss 0.4668
# Epoch 2 Batch 1400 Loss 0.4523
# Epoch 2 Loss 0.5147
# Time taken for 1 epoch 258.67 sec
#
# Epoch 3 Batch 0 Loss 0.2809
# Epoch 3 Batch 100 Loss 0.3898
# Epoch 3 Batch 200 Loss 0.2749
# Epoch 3 Batch 300 Loss 0.3003
# Epoch 3 Batch 400 Loss 0.3544
# Epoch 3 Batch 500 Loss 0.3020
# Epoch 3 Batch 600 Loss 0.3115
# Epoch 3 Batch 700 Loss 0.3540
# Epoch 3 Batch 800 Loss 0.4190
# Epoch 3 Batch 900 Loss 0.3807
# Epoch 3 Batch 1000 Loss 0.3247
# Epoch 3 Batch 1100 Loss 0.2847
# Epoch 3 Batch 1200 Loss 0.3700
# Epoch 3 Batch 1300 Loss 0.2974
# Epoch 3 Batch 1400 Loss 0.2959
# Epoch 3 Loss 0.3140
# Time taken for 1 epoch 258.30 sec
#
# Epoch 4 Batch 0 Loss 0.1930
# Epoch 4 Batch 100 Loss 0.2260
# Epoch 4 Batch 200 Loss 0.1882
# Epoch 4 Batch 300 Loss 0.2149
# Epoch 4 Batch 400 Loss 0.1900
# Epoch 4 Batch 500 Loss 0.3128
# Epoch 4 Batch 600 Loss 0.1854
# Epoch 4 Batch 700 Loss 0.2229
# Epoch 4 Batch 800 Loss 0.2688
# Epoch 4 Batch 900 Loss 0.1971
# Epoch 4 Batch 1000 Loss 0.2936
# Epoch 4 Batch 1100 Loss 0.1972
# Epoch 4 Batch 1200 Loss 0.1381
# Epoch 4 Batch 1300 Loss 0.1691
# Epoch 4 Batch 1400 Loss 0.2252
# Epoch 4 Loss 0.2191
# Time taken for 1 epoch 258.71 sec
#
# Epoch 5 Batch 0 Loss 0.1511
# Epoch 5 Batch 100 Loss 0.1459
# Epoch 5 Batch 200 Loss 0.1171
# Epoch 5 Batch 300 Loss 0.1708
# Epoch 5 Batch 400 Loss 0.1337
# Epoch 5 Batch 500 Loss 0.1690
# Epoch 5 Batch 600 Loss 0.1515
# Epoch 5 Batch 700 Loss 0.1998
# Epoch 5 Batch 800 Loss 0.2004
# Epoch 5 Batch 900 Loss 0.1362
# Epoch 5 Batch 1000 Loss 0.2046
# Epoch 5 Batch 1100 Loss 0.1704
# Epoch 5 Batch 1200 Loss 0.2078
# Epoch 5 Batch 1300 Loss 0.1848
# Epoch 5 Batch 1400 Loss 0.1658
# Epoch 5 Loss 0.1652
# Time taken for 1 epoch 258.43 sec
#
# Epoch 6 Batch 0 Loss 0.1197
# Epoch 6 Batch 100 Loss 0.1057
# Epoch 6 Batch 200 Loss 0.1574
# Epoch 6 Batch 300 Loss 0.1056
# Epoch 6 Batch 400 Loss 0.1262
# Epoch 6 Batch 500 Loss 0.1528
# Epoch 6 Batch 600 Loss 0.1365
# Epoch 6 Batch 700 Loss 0.1372
# Epoch 6 Batch 800 Loss 0.1471
# Epoch 6 Batch 900 Loss 0.1847
# Epoch 6 Batch 1000 Loss 0.1535
# Epoch 6 Batch 1100 Loss 0.1665
# Epoch 6 Batch 1200 Loss 0.1388
# Epoch 6 Batch 1300 Loss 0.2095
# Epoch 6 Batch 1400 Loss 0.1395
# Epoch 6 Loss 0.1308
# Time taken for 1 epoch 259.19 sec
#
# Epoch 7 Batch 0 Loss 0.0823
# Epoch 7 Batch 100 Loss 0.1228
# Epoch 7 Batch 200 Loss 0.0818
# Epoch 7 Batch 300 Loss 0.1114
# Epoch 7 Batch 400 Loss 0.1245
# Epoch 7 Batch 500 Loss 0.1063
# Epoch 7 Batch 600 Loss 0.1032
# Epoch 7 Batch 700 Loss 0.0964
# Epoch 7 Batch 800 Loss 0.1144
# Epoch 7 Batch 900 Loss 0.0899
# Epoch 7 Batch 1000 Loss 0.1179
# Epoch 7 Batch 1100 Loss 0.1295
# Epoch 7 Batch 1200 Loss 0.1277
# Epoch 7 Batch 1300 Loss 0.1131
# Epoch 7 Batch 1400 Loss 0.1754
# Epoch 7 Loss 0.1097
# Time taken for 1 epoch 258.37 sec
#
# Epoch 8 Batch 0 Loss 0.0576
# Epoch 8 Batch 100 Loss 0.0609
# Epoch 8 Batch 200 Loss 0.0589
# Epoch 8 Batch 300 Loss 0.0495
# Epoch 8 Batch 400 Loss 0.0865
# Epoch 8 Batch 500 Loss 0.0894
# Epoch 8 Batch 600 Loss 0.0721
# Epoch 8 Batch 700 Loss 0.0860
# Epoch 8 Batch 800 Loss 0.1088
# Epoch 8 Batch 900 Loss 0.0881
# Epoch 8 Batch 1000 Loss 0.0998
# Epoch 8 Batch 1100 Loss 0.1113
# Epoch 8 Batch 1200 Loss 0.1452
# Epoch 8 Batch 1300 Loss 0.0914
# Epoch 8 Batch 1400 Loss 0.1000
# Epoch 8 Loss 0.0936
# Time taken for 1 epoch 258.81 sec
#
# Epoch 9 Batch 0 Loss 0.0736
# Epoch 9 Batch 100 Loss 0.0607
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b6e3ed9ddc04> in <module>
#       8
#       9     for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
# ---> 10         batch_loss = train_step(inp, targ, enc_hidden)
#      11         total_loss += batch_loss
#      12
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Salva ultimo checkpoint
checkpoint.save(file_prefix=checkpoint_prefix)
